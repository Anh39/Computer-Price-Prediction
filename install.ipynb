# %%
# %pip install aiohttp
# %pip install playwright
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# ...
# Note: you may need to restart the kernel to use updated packages.
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# ...
#    ---------------------------------------- 0.0/29.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/29.4 MB ? eta -:--:--
#    ---------------------------------------- 0.1/29.4 MB 1.1 MB/s eta 0:00:27
#    ---------------------------------------- 0.2/29.4 MB 1.7 MB/s eta 0:00:17
#     --------------------------------------- 0.4/29.4 MB 2.8 MB/s eta 0:00:11
#    - -------------------------------------- 0.9/29.4 MB 4.7 MB/s eta 0:00:07
#    -- ------------------------------------- 1.8/29.4 MB 7.7 MB/s eta 0:00:04
#    ---- ----------------------------------- 3.5/29.4 MB 11.9 MB/s eta 0:00:03
#    ------- -------------------------------- 5.2/29.4 MB 14.9 MB/s eta 0:00:02
#    -------- ------------------------------- 6.3/29.4 MB 17.5 MB/s eta 0:00:02
# ...
